# %% [markdown]
# <a href="https://colab.research.google.com/github/iholthey/JIRA-Export/blob/main/Trello_auslesen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hallo von Google Colab!")
# Out:
# Hallo von Google Colab!
